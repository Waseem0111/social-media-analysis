# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %% [markdown]
# # Generate Random Social Media Data

# %%
# Define categories
categories = ['Food', 'Travel', 'Fashion', 'Fitness', 'Music', 'Culture', 'Family', 'Health']

# Number of records
n = 500

# Generate data
data = {
    'Date': pd.date_range('2021-01-01', periods=n),
    'Category': [random.choice(categories) for _ in range(n)],
    'Likes': np.random.randint(0, 10000, size=n)
}

# %% [markdown]
# # Load Data into DataFrame & Explore

# %%
df = pd.DataFrame(data)

# print first few rows
print(df.head())

# DataFrame into
print(df.info())

# Descriptive stats
print(df.describe())

# count of each category
print(df['Category'].value_counts())
# Out:
#         Date Category  Likes
# 0 2021-01-01    Music   1151
# 1 2021-01-02   Travel   6610
# 2 2021-01-03  Fashion   9971
# 3 2021-01-04     Food   1903
# 4 2021-01-05   Family   8826
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      500 non-null    datetime64[ns]
#  1   Category  500 non-null    object
#  2   Likes     500 non-null    int32
# dtypes: datetime64[ns](1), int32(1), object(1)
# memory usage: 9.9+ KB
# None
#                       Date        Likes
# count                  500   500.000000
# mean   2021-09-07 12:00:00  5147.340000
# min    2021-01-01 00:00:00    20.000000
# 25%    2021-05-05 18:00:00  2526.750000
# 50%    2021-09-07 12:00:00  5263.500000
# 75%    2022-01-10 06:00:00  7771.750000
# max    2022-05-15 00:00:00  9994.000000
# std                    NaN  2948.201348
# Category
# Family     68
# Fashion    67
# Food       66
# Travel     66
# Culture    64
# Music      61
# Health     56
# Fitness    52
# Name: count, dtype: int64

# %% [markdown]
# # Clean the Data

# %%
# Remove nulls
df = df.dropna()

# Remove duplicates (make sure to CALL the function with parentheses)
df = df.drop_duplicates()

# Convert 'Date' to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Convert 'Likes' to int
df['Likes'] = df['Likes'].astype(int)

# %% [markdown]
# # Visualize & Analyze

# %%
# Histogram of likes
sns.histplot(df['Likes'], bins=30)
plt.title('Distribution of Likes')
plt.xlabel('Likes')
plt.ylabel('Frequency')
plt.show()

# Boxplot: Likes by Category
plt.figure(figsize=(12, 6))
sns.boxplot(x='Category', y='Likes', data=df)
plt.title('Likes be Category')
plt.xticks(rotation=45)
plt.show()

# Mean Likes overall
print(f"Average Likes: {df['Likes'].mean():.2f}")

# Mean Likes by Category
print(df.groupby('Category')['Likes'].mean())
# Out:
# Average Likes: 5147.34
# Category
# Culture    5211.093750
# Family     5589.985294
# Fashion    4795.597015
# Fitness    4714.884615
# Food       5042.939394
# Health     5293.321429
# Music      5581.426230
# Travel     4906.590909
# Name: Likes, dtype: float64

# %% [markdown]
# Conclusion:
# This project involved simulating social media post data and analyzing user engagement across categories. I successfully generated random data and used Pandas and Seaborn for data exploration and visualization. Categories like Travel and Food showed higher median likes. This project demonstrates my ability to work with synthetic datasets, perform data cleaning, visualization, and draw actionable insights.
