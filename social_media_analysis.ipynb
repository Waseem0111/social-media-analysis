# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %% [markdown]
# # Generate Random Social Media Data

# %%
# Define categories
categories = ['Food', 'Travel', 'Fashion', 'Fitness', 'Music', 'Culture', 'Family', 'Health']

# Number of records
n = 500

# Generate data
data = {
    'Date': pd.date_range('2021-01-01', periods=n),
    'Category': [random.choice(categories) for _ in range(n)],
    'Likes': np.random.randint(0, 10000, size=n)
}

# %% [markdown]
# # Load Data into DataFrame & Explore

# %%
df = pd.DataFrame(data)

# print first few rows
print(df.head())

# DataFrame into
print(df.info())

# Descriptive stats
print(df.describe())

# count of each category
print(df['Category'].value_counts())
# Out:
#         Date Category  Likes
# 0 2021-01-01  Fitness   9763
# 1 2021-01-02    Music   7904
# 2 2021-01-03  Culture   9649
# 3 2021-01-04  Culture   1674
# 4 2021-01-05     Food   7587
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      500 non-null    datetime64[ns]
#  1   Category  500 non-null    object
#  2   Likes     500 non-null    int32
# dtypes: datetime64[ns](1), int32(1), object(1)
# memory usage: 9.9+ KB
# None
#                       Date        Likes
# count                  500   500.000000
# mean   2021-09-07 12:00:00  4920.488000
# min    2021-01-01 00:00:00    31.000000
# 25%    2021-05-05 18:00:00  2456.000000
# 50%    2021-09-07 12:00:00  5000.500000
# 75%    2022-01-10 06:00:00  7363.250000
# max    2022-05-15 00:00:00  9962.000000
# std                    NaN  2902.740045
# Category
# Family     75
# Health     65
# Fitness    64
# Fashion    64
# Music      60
# Travel     58
# Food       57
# Culture    57
# Name: count, dtype: int64

# %% [markdown]
# # Clean the Data

# %%
# Remove nulls
df = df.dropna()

# Remove duplicates (make sure to CALL the function with parentheses)
df = df.drop_duplicates()

# Convert 'Date' to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Convert 'Likes' to int
df['Likes'] = df['Likes'].astype(int)

# %% [markdown]
# # Visualize & Analyze

# %%
# Histogram of likes
sns.histplot(df['Likes'], bins=30)
plt.title('Distribution of Likes')
plt.xlabel('Likes')
plt.ylabel('Frequency')
plt.show()

# Boxplot: Likes by Category
plt.figure(figsize=(12, 6))
sns.boxplot(x='Category', y='Likes', data=df)
plt.title('Likes be Category')
plt.xticks(rotation=45)
plt.show()

# Mean Likes overall
print(f"Average Likes: {df['Likes'].mean():.2f}")

# Mean Likes by Category
print(df.groupby('Category')['Likes'].mean())
# Out:
# Average Likes: 4920.49
# Category
# Culture    4428.543860
# Family     5299.600000
# Fashion    5213.093750
# Fitness    4779.218750
# Food       4938.912281
# Health     4519.538462
# Music      5043.750000
# Travel     5050.448276
# Name: Likes, dtype: float64

# %% [markdown]
# Conclusion:
# This project involved simulating social media post data and analyzing user engagement across categories. I successfully generated random data and used Pandas and Seaborn for data exploration and visualization. Categories like Travel and Food showed higher median likes. This project demonstrates my ability to work with synthetic datasets, perform data cleaning, visualization, and draw actionable insights.
